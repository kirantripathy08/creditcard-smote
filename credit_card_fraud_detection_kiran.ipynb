# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.style.use('bmh')

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  41683.000000  41683.000000  41683.000000  41682.000000  41682.000000
# mean   26208.345609     -0.222499      0.035454      0.711902      0.186781
# std    12721.514541      1.855101      1.599923      1.490121      1.399707
# min        0.000000    -56.407510    -72.715728    -31.103685     -5.172595
# 25%    16853.000000     -0.974000     -0.533197      0.229759     -0.719018
# 50%    31305.000000     -0.240189      0.093834      0.811276      0.185168
# 75%    36289.000000      1.159396      0.740067      1.443056      1.069459
# max    40784.000000      1.960497     16.713389      4.101716     16.491217
#
#                  V5            V6            V7            V8            V9  \
# count  41682.000000  41682.000000  41682.000000  41682.000000  41682.000000
# mean      -0.234719      0.099510     -0.112246      0.044579      0.193708
# std        1.387375      1.309662      1.238350      1.209428      1.220092
# min      -42.147898    -26.160506    -26.548144    -41.484823     -7.175097
# 25%       -0.842162     -0.638071     -0.598424     -0.151197     -0.568666
# 50%       -0.272258     -0.156277     -0.073482      0.050183      0.071496
# 75%        0.293052      0.485883      0.432308      0.318625      0.906980
# max       34.801666     22.529298     36.677268     20.007208     10.392889
#
#        ...           V21           V22           V23           V24  \
# count  ...  41682.000000  41682.000000  41682.000000  41682.000000
# mean   ...     -0.028417     -0.111341     -0.040301      0.007295
# std    ...      0.744449      0.638250      0.565217      0.593050
# min    ...    -20.262054     -8.593642    -26.751119     -2.836627
# 25%    ...     -0.235257     -0.533250     -0.179117     -0.324744
# 50%    ...     -0.074873     -0.085641     -0.051385      0.060759
# 75%    ...      0.102520      0.300633      0.077243      0.400073
# max    ...     22.614889      5.805795     17.297845      4.014444
#
#                 V25           V26           V27           V28        Amount  \
# count  41682.000000  41682.000000  41682.000000  41682.000000  41682.000000
# mean       0.136259      0.023199      0.008003      0.004864     89.104007
# std        0.436860      0.504139      0.387877      0.341927    237.163503
# min       -7.495741     -1.438650     -8.567638     -9.617915      0.000000
# 25%       -0.127717     -0.329707     -0.063304     -0.006814      7.500000
# 50%        0.175870     -0.064901      0.008653      0.021615     24.000000
# 75%        0.421184      0.304378      0.085015      0.076216     80.000000
# max        5.525093      3.517346     11.135740     33.847808   7879.420000
#
#               Class
# count  41682.000000
# mean       0.002591
# std        0.050837
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.dtypes
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
sns.countplot(x='Class', data=df, palette='CMRmap')
print('Non-fraud transactions: {}%'.format(round(df.Class.value_counts()[0]/len(df)*100.0,2)))
print('Fraud transactions: {}%'.format(round(df.Class.value_counts()[1]/len(df)*100.0,2)))
# Out:
# Non-fraud transactions: 99.74%
# Fraud transactions: 0.26%

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
ax1 = sns.distplot(df['Time'], ax=ax1, color='y')
ax2 = sns.distplot(df['Amount'], ax=ax2, color='r')
ax1.set_title('Distribution of Time', fontsize=13)
ax2.set_title('Distribution of Amount', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Distribution of Amount')

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
df['scaled_amount'] = rs.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rs.fit_transform(df['Time'].values.reshape(-1,1))
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(0, 'scaled_time', scaled_time)
df.head()
# Out:
#    scaled_time  scaled_amount        V1        V2        V3        V4  \
# 0    -1.610671       1.732690 -1.359807 -0.072781  2.536347  1.378155
# 1    -1.610671      -0.293931  1.191857  0.266151  0.166480  0.448154
# 2    -1.610619       4.891862 -1.358354 -1.340163  1.773209  0.379780
# 3    -1.610619       1.372414 -0.966272 -0.185226  1.792993 -0.863291
# 4    -1.610568       0.634345 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053    0.0
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    0.0
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752    0.0
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458    0.0
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153    0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # <p style="color:blue"> Logistic Regression without SMOTE

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Handle missing values
imputer = SimpleImputer(strategy='mean')
x = np.array(df.iloc[:, df.columns != 'Class'])
x = imputer.fit_transform(x)  # Replace NaN with mean
y = np.array(df.iloc[:, df.columns == 'Class'])

if np.isnan(y).any():
    print("Target contains NaN values. Fixing...")
    y = np.nan_to_num(y)

# Ensure y is integer (if stored as float)
y = y.astype(int)

# Verify unique values in y
print("Unique values in target:", np.unique(y))

# Train-test split
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)

# Logistic Regression
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)
cnf_matrix = confusion_matrix(y_test, y_pred)

# Confusion matrix heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

# Classification report
labels = ['Non-fraud', 'Fraud']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
# Unique values in target: [0 1]
#               precision    recall  f1-score   support
#
#    Non-fraud       1.00      1.00      1.00      8316
#        Fraud       0.75      0.57      0.65        21
#
#     accuracy                           1.00      8337
#    macro avg       0.87      0.79      0.82      8337
# weighted avg       1.00      1.00      1.00      8337

# %% [markdown]
# <font size="2" font>As we can see this is not a good model, because it is biased towards majority class and the recall in minority class is not as high as disired

# %%
from imblearn.over_sampling import SMOTE

print("Transaction Number x_train dataset: ", x_train.shape)
print("Transaction Number y_train dataset: ", y_train.shape)
print("Transaction Number x_test dataset: ", x_test.shape)
print("Transaction Number y_test dataset: ", y_test.shape)

print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x_train_s, y_train_s = sm.fit_resample(x_train, y_train.ravel())

print('After OverSampling, the shape of train_x: {}'.format(x_train_s.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_s.shape))

print("After OverSampling, counts of label '1', %: {}".format(sum(y_train_s==1)/len(y_train_s)*100.0,2))
print("After OverSampling, counts of label '0', %: {}".format(sum(y_train_s==0)/len(y_train_s)*100.0,2))

sns.countplot(x=y_train_s, palette='CMRmap')
# Out:
# Transaction Number x_train dataset:  (33346, 30)
# Transaction Number y_train dataset:  (33346, 1)
# Transaction Number x_test dataset:  (8337, 30)
# Transaction Number y_test dataset:  (8337, 1)
# Before OverSampling, counts of label '1': [87]
# Before OverSampling, counts of label '0': [33259]
#
# After OverSampling, the shape of train_x: (66518, 30)
# After OverSampling, the shape of train_y: (66518,)
#
# After OverSampling, counts of label '1', %: 50.0
# After OverSampling, counts of label '0', %: 50.0
# <Axes: ylabel='count'>

# %% [markdown]
# <font size="2" font>Now the dataset is balanced, so we can build a Logistic Regression model with SMOTE. One important thing to point out here is that we used SMOTE after cross validation in order to avoid data leakage problem and hence overfitting

# %% [markdown]
# # <p style="color:blue"> Logistic Regression with SMOTE

# %%
logreg = LogisticRegression()
logreg.fit(x_train_s, y_train_s)
y_pred = logreg.predict(x_test)
cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8316
#            1       0.12      0.86      0.20        21
#
#     accuracy                           0.98      8337
#    macro avg       0.56      0.92      0.60      8337
# weighted avg       1.00      0.98      0.99      8337

# %%
y_pred_prob = logreg.predict_proba(x_test)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(precision, recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %% [markdown]
# # <p style="color:blue"> Random Forest Classifier with SMOTE

# %% [markdown]
# !! ***5 minute*** execution time needed !!

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Configure Random Forest
rand_f = rfc(
    n_estimators=1000,
    min_samples_split=10,
    min_samples_leaf=1,
    max_features='sqrt',  # Updated from 'auto' to 'sqrt'
    max_leaf_nodes=None,
    oob_score=True,
    n_jobs=-1,
    random_state=1
)

# Train Random Forest
rand_f.fit(x_train_s, y_train_s)
y_pred = rand_f.predict(x_test)

# Confusion matrix and heatmap
cnf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8316
#            1       0.94      0.71      0.81        21
#
#     accuracy                           1.00      8337
#    macro avg       0.97      0.86      0.91      8337
# weighted avg       1.00      1.00      1.00      8337

# %%
y_pred_prob = rand_f.predict_proba(x_test)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(precision, recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %% [markdown]
# # <p style="color:blue"> XGBoost

# %%
import xgboost as xgb
model = xgb.XGBClassifier(n_estimators = 5000, max_depth = 30, learning_rate = 0.01)
model.fit(x_train_s, y_train_s)
y_pred = model.predict(x_test)

cnf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8316
#            1       0.89      0.81      0.85        21
#
#     accuracy                           1.00      8337
#    macro avg       0.95      0.90      0.92      8337
# weighted avg       1.00      1.00      1.00      8337

# %% [markdown]
# # <p style="color:blue"> Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
model = Sequential([Dense(input_dim=30, units=16, activation='relu'),
                   Dense(units=24, activation='relu'),
                   Dropout(0.5),
                   Dense(units=20, activation='relu'),
                   Dense(units=24, activation='relu'),
                   Dense(units=1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 24)                  │             408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │             500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 24)                  │             504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              25 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,933 (7.55 KB)
#  Trainable params: 1,933 (7.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train_s, y_train_s, batch_size=15, epochs=15)
# Out:
# Epoch 1/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9592 - loss: 0.1021
# Epoch 2/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9984 - loss: 0.0091
# Epoch 3/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9990 - loss: 0.0056
# Epoch 4/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9991 - loss: 0.0054
# Epoch 5/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9993 - loss: 0.0045
# Epoch 6/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9992 - loss: 0.0052
# Epoch 7/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9992 - loss: 0.0047
# Epoch 8/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9993 - loss: 0.0046
# Epoch 9/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9993 - loss: 0.0042
# Epoch 10/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9991 - loss: 0.0033
# Epoch 11/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9996 - loss: 0.0022
# Epoch 12/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9994 - loss: 0.0035
# Epoch 13/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9994 - loss: 0.0021
# Epoch 14/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9995 - loss: 0.0026
# Epoch 15/15
# 4435/4435 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9994 - loss: 0.0030

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
score = model.evaluate(x_test, y_test)
print(score)
# Out:
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0213
# [0.028597835451364517, 0.9991603493690491]

# %%
y_pred = (model.predict(x_test) > 0.5).astype("int32")

# Confusion matrix and heatmap
cnf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8316
#            1       0.79      0.90      0.84        21
#
#     accuracy                           1.00      8337
#    macro avg       0.90      0.95      0.92      8337
# weighted avg       1.00      1.00      1.00      8337
